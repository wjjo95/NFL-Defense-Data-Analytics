# %%
#SETUP
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Importing Plays data as a data frame
data= pd.read_csv("/content/plays.csv")



#DATA FILTERING
#Selecting relevant columns
SelectedData= data[["playResult", "quarter", "down", "yardsToGo", "playType", "yardlineNumber", "offenseFormation", "defendersInTheBox", "numberOfPassRushers" , "typeDropback", "absoluteYardlineNumber", "passResult" ,"epa"]]

#Removing null
NewData = SelectedData.dropna()



#DATA VISUALIZATION
#Correlation visualization using heatmaps
corrData = NewData.corr()
sns.heatmap(corrData, annot= True, cmap = 'Blues')

# CompData= NewData.loc[(NewData.passResult== "C")]
# InCompData= NewData.loc[(NewData.passResult== "I")]
# corrData = InCompData.corr()
# sns.heatmap(corrData, annot= True, cmap = 'Blues')

# #Facet Grid Visualization
# FacetData = sns.FacetGrid(NewData, col= 'down', row= 'typeDropback', height=4, aspect=1.3)
# FacetData.map(plt.scatter, 'epa', 'playResults')

#Regression Plots
# plt.figure(figsize=(8,6))
# sns.set_context('paper', font_scale=1.4)
# sns.lmplot(x='playResult', y...)

#Logistics Regression Plots
